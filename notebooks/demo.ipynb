# %% [markdown]
# # Demo
#
# The purpose of this notebook is to demonstrate the a basic notebook.
#
# The demo is organised to show
#
# - Step 1: Explanation
#
# - Step 2: Explanation
#
# Note that when you submit a pull request, you should `clear all outputs` from your python notebook for a cleaner merge.

# %%
from pathlib import Path

from amoc_analysis import data, plotting

# %%
ds = data.load_sample_dataset()
# Out:
# Summary for array 'rapid':
# Total datasets loaded: 1
#
# Dataset 1:
#   Source file: moc_transports.nc
#   Time coverage: 2004-04-02 to 2023-02-11
#   Dimensions:
#     - TIME: 13779
#   Variables:
#     - t_therm10: shape (13779,)
#     - t_aiw10: shape (13779,)
#     - t_ud10: shape (13779,)
#     - t_ld10: shape (13779,)
#     - t_bw10: shape (13779,)
#     - t_gs10: shape (13779,)
#     - t_ek10: shape (13779,)
#     - t_umo10: shape (13779,)
#     - moc_mar_hc10: shape (13779,)

# %%
plotting.plot_monthly_transport(ds)
# Out:
# (<Figure size 1200x600 with 1 Axes>,
#  <Axes: title={'center': 'RAPID 26°N - AMOC Transport'}, xlabel='Time', ylabel='overturning transport  [Sv]'>)

# %%
path = Path.cwd().parent / "data" / "temp.nc"
data.save_dataset(ds, output_file=path, prompt_user=True)
# Out:
# Dataset saved to /Users/jakob/Desktop/SS2026/DataAnalysis/template-assignment/data/temp.nc
# True
